# %%
import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# get cwd
cwd = os.getcwd()
cwd
# Out:
# '/Users/desiirani/Documents/py-playground'

# %%
ls
# Out:
# SDFB_people.csv       sherlock.txt          wordcloud.ipynb
# bolt_hometest.csv     train_author_nlp.csv

# %%
# construct the path
file_path = os.path.join(cwd, 'sherlock.txt')

# read the file
with open(file_path, 'r') as file:
    text = file.read()

# %%
# generate a wordcloud image
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure() #i plan to include multiple plots
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
